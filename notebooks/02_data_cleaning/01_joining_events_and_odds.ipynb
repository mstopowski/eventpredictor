# %% [markdown]
# # Imports

# %%
import os
import sys
import json
import glob
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 180)
pd.set_option('display.max_rows', 200)

# %%
sys.path.append(os.path.abspath('../../'))
sys.path.append(os.path.abspath('../../eventpredictor'))

import eventpredictor.config as paths
from eventpredictor.data.download_data import FootballScraper as fs
# Out:
# 2024-06-02 13:56:37.366 | INFO     | config:<module>:11 - PROJ_ROOT path is: /Users/maurycystopowski/Documents/Stuff/Projects/eventpredictor
# 2024-06-02 13:56:37.381 | INFO     | eventpredictor.config:<module>:11 - PROJ_ROOT path is: /Users/maurycystopowski/Documents/Stuff/Projects/eventpredictor

# %% [markdown]
# # Loading data

# %%
events_file_name = os.path.join(paths.SCHEDULED_EVENTS, 'scheduled_events.csv')
odds_file_name = os.path.join(paths.ODDS, 'odds.csv')

# %%
cols_to_select = [
    'id',
    'startTimestamp',
    'tournament_slug',
    'tournament_category_slug',
    'season_name',
    'status_description',
    'status_type',
    'winnerCode',
    'homeTeam_slug',
    'awayTeam_slug',
    'homeScore_period1',
    'homeScore_period2',
    'homeScore_normaltime',
    'awayScore_period1',
    'awayScore_period2',
    'awayScore_normaltime',
]

# %%
events_df = pd.read_csv(events_file_name, usecols=cols_to_select)
events_df = events_df.drop_duplicates()

# %%
odds_df = pd.read_csv(odds_file_name)
odds_df = odds_df.drop_duplicates()

# %% [markdown]
# # Merge and save to csv

# %%
df = events_df.merge(odds_df, on='id', how='left')
df = df.sort_values('startTimestamp')
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (482602, 19)

# %%
df.head()
# Out:
#    winnerCode       id  startTimestamp     tournament_slug  \
# 0         1.0  5714392      1432987200                nb-i
# 1         1.0  6750849      1432987200  2nd-division-avd-4
# 2         2.0  6689991      1432987200  2nd-division-avd-3
# 3         2.0  5617268      1432987200              1-liga
# 4         2.0  5714924      1432989000   regionalliga-west
#
#   tournament_category_slug                     season_name status_description  \
# 0                  hungary                      NB I 14/15              Ended
# 1                   norway       2nd Division, avd. 4 2015              Ended
# 2                   norway       2nd Division, avd. 3 2015              Ended
# 3                   russia  Football National League 14/15              Ended
# 4          austria-amateur         Regionalliga West 14/15              Ended
#
#   status_type           homeTeam_slug     awayTeam_slug  homeScore_period1  \
# 0    finished                  ujpest      kecskemet-te                2.0
# 1    finished                   floro             rodde                2.0
# 2    finished                    fana         flekkeroy                1.0
# 3    finished               fc-tyumen  volgar-astrakhan                0.0
# 4    finished  sc-rheindorf-altach-ii         wsg-tirol                0.0
#
#    homeScore_period2  homeScore_normaltime  awayScore_period1  \
# 0                1.0                   3.0                0.0
# 1                2.0                   4.0                0.0
# 2                0.0                   1.0                0.0
# 3                0.0                   0.0                1.0
# 4                1.0                   1.0                2.0
#
#    awayScore_period2  awayScore_normaltime    1    2    X
# 0                0.0                   0.0  NaN  NaN  NaN
# 1                0.0                   0.0  NaN  NaN  NaN
# 2                2.0                   2.0  NaN  NaN  NaN
# 3                0.0                   1.0  NaN  NaN  NaN
# 4                4.0                   6.0  NaN  NaN  NaN

# %%
df.to_csv(os.path.join(paths.INTERIM_DATA_DIR, 'events_with_odds_merged.csv'), index=False)

# %%
df['startTimestamp'] = pd.to_datetime(df['startTimestamp'], unit='s')

# %%
df.sample(10).T
# Out:
#                                         352174               422636  \
# winnerCode                                 2.0                  1.0
# id                                     9576394             10913571
# startTimestamp             2021-10-16 14:00:00  2023-02-04 12:00:00
# tournament_slug                 premier-league        thai-league-1
# tournament_category_slug               england             thailand
# season_name               Premier League 21/22  Thai League 1 22/23
# status_description                       Ended                Ended
# status_type                           finished             finished
# homeTeam_slug                      aston-villa            sukhothai
# awayTeam_slug                    wolverhampton   muang-thong-united
# homeScore_period1                          0.0                  1.0
# homeScore_period2                          NaN                  1.0
# homeScore_normaltime                       2.0                  2.0
# awayScore_period1                          0.0                  0.0
# awayScore_period2                          NaN                  1.0
# awayScore_normaltime                       3.0                  1.0
# 1                                          1/1                 11/5
# 2                                          3/1                  1/1
# X                                          9/4                  5/2
#
#                                           209774  \
# winnerCode                                   1.0
# id                                       8231022
# startTimestamp               2019-07-31 00:30:00
# tournament_slug            conmebol-sudamericana
# tournament_category_slug           south-america
# season_name               Copa Sudamericana 2019
# status_description                         Ended
# status_type                             finished
# homeTeam_slug                         fluminense
# awayTeam_slug                            penarol
# homeScore_period1                            2.0
# homeScore_period2                            1.0
# homeScore_normaltime                         3.0
# awayScore_period1                            0.0
# awayScore_period2                            1.0
# awayScore_normaltime                         1.0
# 1                                            4/5
# 2                                           10/3
# X                                           13/5
#
#                                                   73010   \
# winnerCode                                           2.0
# id                                               7105666
# startTimestamp                       2016-11-05 12:00:00
# tournament_slug                                   1-liga
# tournament_category_slug                          russia
# season_name               Football National League 16/17
# status_description                                 Ended
# status_type                                     finished
# homeTeam_slug                           mordovia-saransk
# awayTeam_slug                          spartak-moscow-ii
# homeScore_period1                                    1.0
# homeScore_period2                                    0.0
# homeScore_normaltime                                 1.0
# awayScore_period1                                    0.0
# awayScore_period2                                    4.0
# awayScore_normaltime                                 4.0
# 1                                                    6/5
# 2                                                   12/5
# X                                                   11/5
#
#                                             273219               258753  \
# winnerCode                                     2.0                  3.0
# id                                         9007934              8658107
# startTimestamp                 2020-09-16 16:00:00  2020-06-10 15:00:00
# tournament_slug                club-friendly-games         1st-division
# tournament_category_slug                     world              denmark
# season_name               Club Friendly Games 2020   1st Division 19/20
# status_description                           Ended                Ended
# status_type                               finished             finished
# homeTeam_slug                          cd-mosconia              hb-koge
# awayTeam_slug                  real-oviedo-vetusta        fc-fredericia
# homeScore_period1                              0.0                  1.0
# homeScore_period2                              0.0                  NaN
# homeScore_normaltime                           0.0                  2.0
# awayScore_period1                              3.0                  1.0
# awayScore_period2                              2.0                  NaN
# awayScore_normaltime                           5.0                  2.0
# 1                                              NaN                  2/1
# 2                                              NaN                13/10
# X                                              NaN                 12/5
#
#                                                     181675  \
# winnerCode                                             3.0
# id                                                 8089386
# startTimestamp                         2019-01-12 23:00:00
# tournament_slug                           liga-mx-clausura
# tournament_category_slug                            mexico
# season_name               Primera Division 18/19. Clausura
# status_description                                   Ended
# status_type                                       finished
# homeTeam_slug                                    monterrey
# awayTeam_slug                                    club-leon
# homeScore_period1                                      0.0
# homeScore_period2                                      2.0
# homeScore_normaltime                                   2.0
# awayScore_period1                                      0.0
# awayScore_period2                                      2.0
# awayScore_normaltime                                   2.0
# 1                                                    13/20
# 2                                                      4/1
# X                                                      3/1
#
#                                        296422                428547  \
# winnerCode                                2.0                   3.0
# id                                    8738668              10388638
# startTimestamp            2020-12-23 20:00:00   2023-03-12 12:30:00
# tournament_slug                       ligue-1          2-bundesliga
# tournament_category_slug               france               germany
# season_name                     Ligue 1 20/21  2nd Bundesliga 22/23
# status_description                      Ended                 Ended
# status_type                          finished              finished
# homeTeam_slug                     montpellier           hannover-96
# awayTeam_slug                           lille      fc-hansa-rostock
# homeScore_period1                         0.0                   0.0
# homeScore_period2                         NaN                   1.0
# homeScore_normaltime                      2.0                   1.0
# awayScore_period1                         1.0                   1.0
# awayScore_period2                         NaN                   0.0
# awayScore_normaltime                      3.0                   1.0
# 1                                        14/5                   6/5
# 2                                       21/20                 23/10
# X                                       23/10                  12/5
#
#                                             182104
# winnerCode                                     1.0
# id                                         8102709
# startTimestamp                 2019-01-19 10:00:00
# tournament_slug                club-friendly-games
# tournament_category_slug                     world
# season_name               Club Friendly Games 2019
# status_description                           Ended
# status_type                               finished
# homeTeam_slug                           as-trencin
# awayTeam_slug                     slezsky-fc-opava
# homeScore_period1                              1.0
# homeScore_period2                              0.0
# homeScore_normaltime                           1.0
# awayScore_period1                              0.0
# awayScore_period2                              0.0
# awayScore_normaltime                           0.0
# 1                                              NaN
# 2                                              NaN
# X                                              NaN

# %% [markdown]
# # Tournaments with more than 2000 rows

# %%
countries_to_remove = {
    'africa',
    'asia',
    'esoccer',
    'europe',
    'international',
    'north-central-america',
    'oceania',
    'simulated-reality-women',
    'south-africa',
    'south-america',
    'world'
}

# %%
selected_tournaments = df[~df['tournament_category_slug'].isin(countries_to_remove)][['tournament_category_slug', 'tournament_slug', 'id']]\
    .groupby(['tournament_category_slug', 'tournament_slug'], as_index=False)['id'].count()
selected_tournaments = selected_tournaments[selected_tournaments['id'] > 2000].reset_index(drop=True).rename(columns={'id': 'count'})

# %%
selected_tournaments
# Out:
#    tournament_category_slug         tournament_slug  count
# 0                   algeria                 ligue-1   2436
# 1                 argentina        liga-profesional   3189
# 2                 argentina      primera-b-nacional   2397
# 3                   belarus         vysshaya-league   2091
# 4                   belgium              pro-league   2429
# 5                    brazil     brasileirao-serie-a   3424
# 6                    brazil     brasileirao-serie-b   3422
# 7            czech-republic                  1-liga   2225
# 8            czech-republic                     fnl   2077
# 9                     egypt          premier-league   2791
# 10                  england            championship   5060
# 11                  england              league-one   5125
# 12                  england              league-two   5211
# 13                  england         national-league   5313
# 14                  england          premier-league   3438
# 15                   france                 ligue-1   3232
# 16                   france                 ligue-2   3409
# 17                   france              national-1   2481
# 18                  germany            2-bundesliga   2763
# 19                  germany                  3-liga   3504
# 20                  germany              bundesliga   2707
# 21          germany-amateur    regionalliga-bavaria   2735
# 22          germany-amateur      regionalliga-north   2322
# 23          germany-amateur  regionalliga-northeast   3073
# 24          germany-amateur  regionalliga-southwest   3093
# 25          germany-amateur       regionalliga-west   3169
# 26                    ghana          premier-league   2305
# 27                   greece  stoiximan-super-league   2051
# 28                indonesia                  liga-1   2769
# 29                    italy                 serie-a   3427
# 30                    italy                 serie-b   3708
# 31                    italy        serie-c-girone-a   3317
# 32                    italy        serie-c-girone-b   3259
# 33                    italy        serie-c-girone-c   3228
# 34                    japan                 jleague   2742
# 35                    japan               jleague-2   4033
# 36                  morocco                  botola   2190
# 37              netherlands          eerste-divisie   3380
# 38              netherlands              eredivisie   2759
# 39                   norway            1st-division   2134
# 40                   norway             eliteserien   2108
# 41                   poland             ekstraklasa   2259
# 42                   poland                  i-liga   2719
# 43                 portugal         liga-portugal-2   3260
# 44                 portugal   liga-portugal-betclic   2743
# 45                   russia                  1-liga   3240
# 46                   russia            premier-liga   2073
# 47                   serbia   mozzart-bet-superliga   2250
# 48                    spain                  laliga   3422
# 49                    spain                laliga-2   4135
# 50                    spain                  liga-f   2262
# 51                   sweden             allsvenskan   2084
# 52                   sweden              superettan   2106
# 53                 thailand           thai-league-1   2263
# 54                   turkey    tff-2-lig-beyaz-grup   2518
# 55                   turkey  tff-2-lig-kirmizi-grup   2667
# 56                   turkey        tff-3-lig-grup-1   2421
# 57                   turkey        tff-3-lig-grup-2   2416
# 58                   turkey        tff-3-lig-grup-3   2434
# 59                   turkey           trendyol-1lig   2830
# 60                   turkey      trendyol-super-lig   3155
# 61                      usa                     mls   3502
# 62                      usa        usl-championship   3845

# %%
selected_tournaments_set = (selected_tournaments['tournament_category_slug'] + selected_tournaments['tournament_slug']).values

# %%
df = df.loc[(df['tournament_category_slug'] + df['tournament_slug']).isin(selected_tournaments_set)]
df = df.sort_values('startTimestamp').reset_index(drop=True)
df = df.reset_index(drop=True)

# %%
df.sample(5)
# Out:
#         winnerCode        id      startTimestamp         tournament_slug  \
# 141746         1.0   9645722 2022-02-20 11:30:00                 serie-a
# 169828         3.0  10388709 2023-05-07 11:30:00            2-bundesliga
# 120902         2.0   9238655 2021-03-14 17:00:00  stoiximan-super-league
# 31689          1.0   7127106 2016-12-03 15:00:00         national-league
# 113901         3.0   9196926 2020-12-10 12:00:00            1st-division
#
#        tournament_category_slug            season_name status_description  \
# 141746                    italy          Serie A 21/22              Ended
# 169828                  germany   2nd Bundesliga 22/23              Ended
# 120902                   greece   Super League 1 20/21              Ended
# 31689                   england  National League 16/17              Ended
# 113901                   norway      1st Division 2020              Ended
#
#        status_type         homeTeam_slug   awayTeam_slug  homeScore_period1  \
# 141746    finished            fiorentina        atalanta                0.0
# 169828    finished       1-fc-heidenheim  1-fc-magdeburg                0.0
# 120902    finished             ae-larisa      olympiacos                0.0
# 31689     finished  north-ferriby-united       gateshead                1.0
# 113901    finished           strommen-if  stjordalsblink                1.0
#
#         homeScore_period2  homeScore_normaltime  awayScore_period1  \
# 141746                1.0                   1.0                0.0
# 169828                0.0                   0.0                0.0
# 120902                NaN                   1.0                1.0
# 31689                 0.0                   1.0                0.0
# 113901                NaN                   1.0                1.0
#
#         awayScore_period2  awayScore_normaltime       1        2     X
# 141746                0.0                   0.0   31/20  163/100   5/2
# 169828                0.0                   0.0   11/20     19/4  10/3
# 120902                NaN                   3.0     9/1   33/100   7/2
# 31689                 0.0                   0.0     6/1     9/20  10/3
# 113901                NaN                   1.0  83/100      9/4   3/1

# %%
df.shape
# Out:
# (187130, 19)

# %% [markdown]
# # status_description filtering

# %%
status_description_set = {
    # 'Abandoned',
    'Ended', 
    # 'Retired', 
    # 'Walkover', 
}

# %%
df['status_description'].value_counts()
# Out:
# status_description
# Ended                178291
# Canceled               6260
# Postponed              2534
# Abandoned                15
# AP                       10
# Retired                   8
# Walkover                  7
# AET                       4
# Coverage canceled         1
# Name: count, dtype: int64

# %%
df = df[df['status_description'].isin(status_description_set)]
df = df.sort_values('startTimestamp')
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (178291, 19)

# %%
df.isna().sum()
# Out:
# winnerCode                     11
# id                              0
# startTimestamp                  0
# tournament_slug                 0
# tournament_category_slug        0
# season_name                    15
# status_description              0
# status_type                     0
# homeTeam_slug                   0
# awayTeam_slug                   0
# homeScore_period1             848
# homeScore_period2           43006
# homeScore_normaltime          469
# awayScore_period1             848
# awayScore_period2           43004
# awayScore_normaltime          469
# 1                           14325
# 2                           14324
# X                           14316
# dtype: int64

# %% [markdown]
# # Missing data

# %% [markdown]
# ## home/awayScore

# %%
df.loc[(df['homeScore_period1'].notna()) & (df['homeScore_period2'].notna()) & (df['homeScore_normaltime'].isna()), 'homeScore_normaltime'] = df['homeScore_period1'] + df['homeScore_period2']
df.loc[(df['homeScore_period1'].notna()) & (df['homeScore_normaltime'].notna()) & (df['homeScore_period2'].isna()), 'homeScore_period2'] = df['homeScore_normaltime'] - df['homeScore_period1']
df.loc[(df['homeScore_period2'].notna()) & (df['homeScore_normaltime'].notna()) & (df['homeScore_period1'].isna()), 'homeScore_period1'] = df['homeScore_normaltime'] - df['homeScore_period2']

# %%
df.loc[(df['awayScore_period1'].notna()) & (df['awayScore_period2'].notna()) & (df['awayScore_normaltime'].isna()), 'awayScore_normaltime'] = df['awayScore_period1'] + df['awayScore_period2']
df.loc[(df['awayScore_period1'].notna()) & (df['awayScore_normaltime'].notna()) & (df['awayScore_period2'].isna()), 'awayScore_period2'] = df['awayScore_normaltime'] - df['awayScore_period1']
df.loc[(df['awayScore_period2'].notna()) & (df['awayScore_normaltime'].notna()) & (df['awayScore_period1'].isna()), 'awayScore_period1'] = df['awayScore_normaltime'] - df['awayScore_period2']

# %%
df.isna().sum()
# Out:
# winnerCode                     11
# id                              0
# startTimestamp                  0
# tournament_slug                 0
# tournament_category_slug        0
# season_name                    15
# status_description              0
# status_type                     0
# homeTeam_slug                   0
# awayTeam_slug                   0
# homeScore_period1             840
# homeScore_period2            1299
# homeScore_normaltime          465
# awayScore_period1             840
# awayScore_period2            1299
# awayScore_normaltime          465
# 1                           14325
# 2                           14324
# X                           14316
# dtype: int64

# %% [markdown]
# ## season_name

# %%
for row in df.loc[df['season_name'].isna(), ['id', 'startTimestamp', 'tournament_category_slug', 'tournament_slug']].values:
    row_id, row_timestamp, row_country, row_tournament = row
    
    temp_df = df.loc[(df['season_name'].notna()) & (df['tournament_category_slug'] == row_country) & (df['tournament_slug'] == row_tournament)].sort_values('startTimestamp').reset_index(drop=True)
    date_index = abs(temp_df['startTimestamp'] - row_timestamp).sort_values().index[0]
    season_name_imput = temp_df.iloc[date_index]['season_name']

    df.loc[df['id'] == row_id, 'season_name'] = season_name_imput

# %% [markdown]
# ## odds

# %%
split_len = df['1'].str.split('/').str.len()
split_len = split_len[split_len == 1].index
df.loc[split_len, '1'] = pd.NA

split_len = df['2'].str.split('/').str.len()
split_len = split_len[split_len == 1].index
df.loc[split_len, '2'] = pd.NA

split_len = df['X'].str.split('/').str.len()
split_len = split_len[split_len == 1].index
df.loc[split_len, 'X'] = pd.NA

# %% [markdown]
# calculate missing odds per tournament season

# %%
df_count = df.loc[:, ['tournament_category_slug', 'tournament_slug', 'season_name', 'id']]\
    .groupby(by=['tournament_category_slug', 'tournament_slug', 'season_name'], as_index=False).count().rename(columns={'id': 'size'})

df_1_null = df.loc[:, ['tournament_category_slug', 'tournament_slug', 'season_name', '1']]\
    .groupby(by=['tournament_category_slug', 'tournament_slug', 'season_name'], as_index=False).agg({'1': lambda x: x.isnull().sum()})

df_X_null = df.loc[:, ['tournament_category_slug', 'tournament_slug', 'season_name', 'X']]\
    .groupby(by=['tournament_category_slug', 'tournament_slug', 'season_name'], as_index=False).agg({'X': lambda x: x.isnull().sum()})

df_2_null = df.loc[:, ['tournament_category_slug', 'tournament_slug', 'season_name', '2']]\
    .groupby(by=['tournament_category_slug', 'tournament_slug', 'season_name'], as_index=False).agg({'2': lambda x: x.isnull().sum()})

# %%
df_odds = df_count.merge(df_1_null, on=['tournament_category_slug', 'tournament_slug', 'season_name'])\
    .merge(df_X_null, on=['tournament_category_slug', 'tournament_slug', 'season_name'])\
        .merge(df_2_null, on=['tournament_category_slug', 'tournament_slug', 'season_name'])

df_odds['1_%'] = round(df_odds['1'] / df_odds['size'], 2)
df_odds['X_%'] = round(df_odds['X'] / df_odds['size'], 2)
df_odds['2_%'] = round(df_odds['2'] / df_odds['size'], 2)

limit = 0.12
df_odds['remove'] = False
df_odds.loc[df_odds['1_%'].gt(limit) | df_odds['X_%'].gt(limit) | df_odds['2_%'].gt(limit), 'remove'] = True

# %%
df_odds.sample(25)
# Out:
#     tournament_category_slug         tournament_slug  \
# 17                 argentina        liga-profesional
# 428                   serbia   mozzart-bet-superliga
# 104                  england              league-one
# 292                    italy        serie-c-girone-b
# 395                 portugal   liga-portugal-betclic
# 71            czech-republic                     fnl
# 306                    japan                 jleague
# 526                   turkey        tff-3-lig-grup-3
# 78            czech-republic                     fnl
# 383                   poland                  i-liga
# 222          germany-amateur       regionalliga-west
# 434                    spain                  laliga
# 370                   poland             ekstraklasa
# 476                   sweden              superettan
# 101                  england              league-one
# 51                    brazil     brasileirao-serie-b
# 471                   sweden              superettan
# 538                   turkey      trendyol-super-lig
# 40                   belgium              pro-league
# 75            czech-republic                     fnl
# 425                   serbia   mozzart-bet-superliga
# 386                 portugal         liga-portugal-2
# 201          germany-amateur      regionalliga-north
# 244                   greece  stoiximan-super-league
# 220          germany-amateur  regionalliga-southwest
#
#                       season_name  size    1    X    2   1_%   X_%   2_%  \
# 17                 Superliga 2021   325    1    1    2  0.00  0.00  0.01
# 428               Superliga 21/22   240   13   14   13  0.05  0.06  0.05
# 104              League One 20/21   552    0    0    0  0.00  0.00  0.00
# 292        Serie C, Group B 21/22   380   21   22   21  0.06  0.06  0.06
# 395           Primeira Liga 15/16   306    0    0    0  0.00  0.00  0.00
# 71                      FNL 15/16   210    0    0    0  0.00  0.00  0.00
# 306                 J.League 2018   306    0    0    0  0.00  0.00  0.00
# 526                 3rd Lig 17/18   303  303  303  303  1.00  1.00  1.00
# 78                      FNL 22/23   240    8    8    8  0.03  0.03  0.03
# 383                  I Liga 22/23   306    0    0    0  0.00  0.00  0.00
# 222       Regionalliga West 15/16   342    2    2    2  0.01  0.01  0.01
# 434                  LaLiga 19/20   380    0    0    0  0.00  0.00  0.00
# 370             Ekstraklasa 19/20   240    0    0    0  0.00  0.00  0.00
# 476               Superettan 2023   240    0    0    0  0.00  0.00  0.00
# 101              League One 17/18   552    0    0    0  0.00  0.00  0.00
# 51        Brasileiro Serie B 2015   346    6    6    6  0.02  0.02  0.02
# 471               Superettan 2018   240    0    0    0  0.00  0.00  0.00
# 538               Super Lig 16/17   306    0    0    0  0.00  0.00  0.00
# 40               Pro League 22/23   304    0    0    0  0.00  0.00  0.00
# 75                      FNL 19/20   240    0    0    0  0.00  0.00  0.00
# 425               Superliga 18/19   240    0    0    0  0.00  0.00  0.00
# 386         Liga Portugal 2 22/23   306    0    0    0  0.00  0.00  0.00
# 201      Regionalliga North 19/20   211    9    9    9  0.04  0.04  0.04
# 244          Super League 1 21/22   182    0    0    0  0.00  0.00  0.00
# 220  Regionalliga Southwest 22/23   306   27   27   27  0.09  0.09  0.09
#
#      remove
# 17    False
# 428   False
# 104   False
# 292   False
# 395   False
# 71    False
# 306   False
# 526    True
# 78    False
# 383   False
# 222   False
# 434   False
# 370   False
# 476   False
# 101   False
# 51    False
# 471   False
# 538   False
# 40    False
# 75    False
# 425   False
# 386   False
# 201   False
# 244   False
# 220   False

# %%
df_odds_remove = df_odds.loc[df_odds['remove'] == False]
odds_set = (df_odds_remove['tournament_category_slug'] + df_odds_remove['tournament_slug'] + df_odds_remove['season_name']).values

# %%
df = df.loc[(df['tournament_category_slug'] + df['tournament_slug'] + df['season_name']).isin(odds_set)]
df = df.sort_values('startTimestamp').reset_index(drop=True)

# %%
df.shape
# Out:
# (156097, 19)

# %% [markdown]
# ## remaining missing data

# %%
df.isna().sum()
# Out:
# winnerCode                    11
# id                             0
# startTimestamp                 0
# tournament_slug                0
# tournament_category_slug       0
# season_name                    0
# status_description             0
# status_type                    0
# homeTeam_slug                  0
# awayTeam_slug                  0
# homeScore_period1            579
# homeScore_period2            932
# homeScore_normaltime         359
# awayScore_period1            579
# awayScore_period2            932
# awayScore_normaltime         359
# 1                           1350
# 2                           1353
# X                           1348
# dtype: int64

# %% [markdown]
# # Save df to csv

# %%
df.to_csv(os.path.join(paths.INTERIM_DATA_DIR, 'events_with_odds_filtered.csv'), index=False)
